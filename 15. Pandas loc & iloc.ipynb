# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\student.csv')
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df.loc[0]   # input as lable or index
# Out:
# Student ID                1001.0
# Class                       10.0
# Study hrs                    2.0
# Sleeoing hrs                 8.0
# social media usage hrs       6.0
# Moble Games hrs              2.0
# Percentage                  50.0
# Name: 0, dtype: float64

# %%
df.loc[11]
# Out:
# Student ID                1012.0
# Class                       12.0
# Study hrs                    6.0
# Sleeoing hrs                 2.0
# social media usage hrs       4.0
# Moble Games hrs              2.0
# Percentage                  89.0
# Name: 11, dtype: float64

# %%
#list of lables
df.loc[[0,1,2,11]]
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# 0                 2          50
# 1                 3          60
# 2                 1          70
# 11                2          89

# %%
df.loc[11,'Class'] #specific value
# Out:
# 12

# %%
#slice object with lables

# %%
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df.loc[0:3 , 'Class']
# Out:
# 0    10
# 1    10
# 2    10
# 3    10
# Name: Class, dtype: int64

# %%
df.loc[0:3 , 'Student ID']
# Out:
# 0    1001
# 1    1002
# 2    1003
# 3    1004
# Name: Student ID, dtype: int64

# %%
# boolean format 
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df.loc[df['Class']<11]
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2           8.0                       6
# 1        1002     10          6           5.0                       6
# 2        1003     10          3           6.0                       4
# 3        1004     10          3           8.0                       5
# 9        1010     10          6           NaN                       7
#
#    Moble Games hrs  Percentage
# 0                2          50
# 1                3          60
# 2                1          70
# 3                2          75
# 9                6          84

# %%
df.loc[df['Class']<11 ,['Percentage']]
# Out:
#    Percentage
# 0          50
# 1          60
# 2          70
# 3          75
# 9          84

# %% [markdown]
# ## iloc

# %%
df
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 1         1002     10          6           5.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 4         1005     11          0           9.0                       3
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 7         1008     12         10           4.0                       8
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 10        1011     12          2           6.0                       2
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# ...

# %%
df.iloc[0]
# Out:
# Student ID                1001.0
# Class                       10.0
# Study hrs                    2.0
# Sleeoing hrs                 8.0
# social media usage hrs       6.0
# Moble Games hrs              2.0
# Percentage                  50.0
# Name: 0, dtype: float64

# %%
df.iloc[[0]]
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2           8.0                       6
#
#    Moble Games hrs  Percentage
# 0                2          50

# %%
#slice
df.iloc[: , 0]
# Out:
# 0     1001
# 1     1002
# 2     1003
# 3     1004
# 4     1005
# 5     1006
# 6     1007
# 7     1008
# 8     1009
# 9     1010
# 10    1011
# 11    1012
# Name: Student ID, dtype: int64

# %%
#list of lable
df.iloc[[0,1]]
# Out:
#    Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0        1001     10          2           8.0                       6
# 1        1002     10          6           5.0                       6
#
#    Moble Games hrs  Percentage
# 0                2          50
# 1                3          60

# %%
#boolean
df.iloc[[True,False,True,True,False,True,True,False,True,True,False,True]]
# Out:
#     Student ID  Class  Study hrs  Sleeoing hrs  social media usage hrs  \
# 0         1001     10          2           8.0                       6
# 2         1003     10          3           6.0                       4
# 3         1004     10          3           8.0                       5
# 5         1006     11          4           6.0                       5
# 6         1007     11         10           5.0                       6
# 8         1009     12          2           2.0                       9
# 9         1010     10          6           NaN                       7
# 11        1012     12          6           2.0                       4
#
#     Moble Games hrs  Percentage
# 0                 2          50
# 2                 1          70
# 3                 2          75
# 5                 4          85
# 6                 5          95
# 8                 1          95
# 9                 6          84
# 11                2          89
