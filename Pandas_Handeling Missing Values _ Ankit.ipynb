# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv')

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %% [markdown]
# # NAN - not a number
# ![image.png](attachment:image.png)

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv' )
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv' )
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace             no valus       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
# if more then one avilable then will give na_values in list
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv' , na_values= ['not available', 'no valus'] )
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
# specific columns want to consider as NaN then will use dictonary
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv')

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace             no valus       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_missing.csv')

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv' , na_values= {'Companies':'no values', 'Growth': 'not available'})

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv' , na_values= ['not available', 'no values'] )

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %% [markdown]
# ## keep_default_na

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv' , na_values= ['not available', 'no values'] )

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace                  NaN       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv')

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv', keep_default_na=False)

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                 #N/A       2009  $10,573,990
# 5   6         Techline                 #N/A       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                            2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv', keep_default_na=True)

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %% [markdown]
# ## na_filter

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  if you are sure that there are no missing values or irrelevant details in your data then by using na_filter function you can boost the process of data parsing . Parsing means syntax analysis process of analysing a string of symbols .

# %%
 df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10.csv')

# %%
 df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10.csv', na_filter=False)

# %%
df
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %% [markdown]
# ## Null check

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
 df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10.csv')

# %%
df.isnull()
# Out:
#       ID   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False     False      False    False     False   False   False
# 1  False  False     False      False    False     False   False   False
# 2  False  False     False      False    False     False   False   False
# 3  False  False     False      False    False     False   False   False
# 4  False  False     False      False    False     False   False   False
# 5  False  False     False      False    False     False   False   False
# 6  False  False     False      False    False     False   False   False
# 7  False  False     False      False    False     False   False   False
# 8  False  False     False      False    False     False   False   False
# 9  False  False     False      False    False     False   False   False

# %%
 df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv')

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.isnull()
# Out:
#       ID   Name  Companies   Inception  Revenue  Expenses  Profit  Growth
# 0  False  False       False      False    False     False   False   False
# 1  False  False       False      False    False     False   False   False
# 2  False  False       False      False    False     False   False   False
# 3  False  False       False      False    False     False   False   False
# 4  False  False        True      False    False     False   False    True
# 5  False  False        True      False    False     False   False   False
# 6  False  False       False      False    False     False   False   False
# 7  False  False        True      False    False     False   False   False
# 8  False  False       False      False    False      True   False   False
# 9  False  False       False      False    False     False   False   False

# %%
# to find in which column null value is present 
df.isnull().sum()
# Out:
# ID            0
# Name          0
# Companies     3
# Inception     0
# Revenue       0
# Expenses      1
# Profit        0
# Growth        1
# dtype: int64

# %%
# to find total null  values in datas
df.isnull().sum().sum()
# Out:
# 5

# %% [markdown]
# ## pandas.notnull

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_miss.csv')

# %%
df
# Out:
#    ID             Name           Companies   Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill                  NaN       2009  $10,573,990
# 5   6         Techline                  NaN       2006  $13,898,119
# 6   7          Cityace            no values       2010   $9,254,614
# 7   8   Kayelectronics                  NaN       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            20%
# 2  7,591,189 Dollars   3005820             7%
# ...

# %%
df.notnull()  # True mena not null , False means NaN value
# Out:
#      ID  Name  Companies   Inception  Revenue  Expenses  Profit  Growth
# 0  True  True        True       True     True      True    True    True
# 1  True  True        True       True     True      True    True    True
# 2  True  True        True       True     True      True    True    True
# 3  True  True        True       True     True      True    True    True
# 4  True  True       False       True     True      True    True   False
# 5  True  True       False       True     True      True    True    True
# 6  True  True        True       True     True      True    True    True
# 7  True  True       False       True     True      True    True    True
# 8  True  True        True       True     True     False    True    True
# 9  True  True        True       True     True      True    True    True

# %%
df.notnull().sum()
# Out:
# ID            10
# Name          10
# Companies      7
# Inception     10
# Revenue       10
# Expenses       9
# Profit        10
# Growth         9
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 75

# %% [markdown]
#  ## dropna

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_drop.csv')

# %%
df
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %%
df.dropna()
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1) #will drop columns
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   3138627

# %%
df.dropna(how='any') # row drop where Nan Value
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%

# %%
df.dropna(axis=1 ,how='any') # row drop where Nan Value
# Out:
#    ID    Profit
# 0   1   5274553
# 1   2  11412916
# 2   3   3005820
# 3   4   6597557
# 4   5   3138627

# %%
df.dropna(how='all') # if we take all and if any row or column has all NaN value then it will drop it
# Out:
#    ID             Name            Industry    Profit Growth
# 0   1          Lamtone         IT Services   5274553    30%
# 1   2        Stripfind  Financial Services  11412916    20%
# 2   3  Canecorporation              Health   3005820     7%
# 3   4              NaN         IT Services   6597557    NaN
# 4   5        Techdrill                 NaN   3138627     8%

# %% [markdown]
# ## Thresh

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_thresh.csv')

# %%
df
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%
# 3   4              NaN         IT Services   6597557.0    NaN
# 4   5              NaN                 NaN         NaN    NaN

# %%
df.dropna(how='all')
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%
# 3   4              NaN         IT Services   6597557.0    NaN
# 4   5              NaN                 NaN         NaN    NaN

# %%
df.dropna(thresh=2)
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%
# 3   4              NaN         IT Services   6597557.0    NaN

# %%
df.dropna(thresh=4)
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%

# %% [markdown]
# ## Subset

# %% [raw]
# we use subset when we want to drop specific column Nan Value or place

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_thresh.csv')

# %%
df
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%
# 3   4              NaN         IT Services   6597557.0    NaN
# 4   5              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['ID'])
# Out:
#    ID             Name            Industry      Profit Growth
# 0   1          Lamtone         IT Services   5274553.0    30%
# 1   2        Stripfind  Financial Services  11412916.0    20%
# 2   3  Canecorporation              Health   3005820.0     7%
# 3   4              NaN         IT Services   6597557.0    NaN
# 4   5              NaN                 NaN         NaN    NaN

# %%
df = pd.read_csv('C:\\Users\\bmbar\\Desktop\\Python Practise\\Pandas\\fortune_10_ts.csv')

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(subset = ['ID'])
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN

# %%
df.dropna(subset = ['Name'])
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %%
df.dropna(subset = ['Profit'])
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN

# %%
df.dropna(subset = ['Growth'])
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%

# %% [markdown]
# # inplace

# %% [markdown]
# we will give input in Boolean format if we give as TRUE it will update existing data frame will not create new  and drop NaN value

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
# 3  4.0              NaN         IT Services   6597557.0    NaN
# 4  NaN              NaN                 NaN         NaN    NaN

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#     ID             Name            Industry      Profit Growth
# 0  1.0          Lamtone         IT Services   5274553.0    30%
# 1  2.0        Stripfind  Financial Services  11412916.0    20%
# 2  3.0  Canecorporation              Health   3005820.0     7%
